# %%
import warnings
from collections import Counter
from datetime import timedelta
from enum import Enum

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
import pandas as pd
import seaborn as sns
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud


stopwords = stopwords.words("english")


class Sentiment(Enum):
    NEGATIVE = "NEGATIVE"
    NEUTRAL = "NEUTRAL"
    POSITIVE = "POSITIVE"
    MIXED = "MIXED"


sns.set_palette("mako")

warnings.filterwarnings("ignore")

MONTH = "October"

# %%
# load data
# df = pd.read_csv(r"aws and vader_oct_result.csv")
df = pd.read_csv(r"Final__oct_result.csv")
df.shape
# Out:
# (31650, 24)

# %%
df.columns
# Out:
# Index(['User', 'Date_Created', 'Follows_Count', 'Friends_Count',
#        'Retweet_Count', 'Language', 'Date_Tweet', 'Number_of_Likes',
#        'Source_of_Tweet', 'Tweet_Id', 'Tweet', 'Hashtags', 'Conversation_Id',
#        'In_reply_To', 'Coordinates', 'Place', 'Date_Tweet1', 'lower',
#        'cleaned_text', 'Sentiment', 'vader', 'textblob', 'xgb',
#        'Majority_label'],
#       dtype='object')

# %%
# drop Sentiment and rename Majority_label to Sentiment
df = df.drop(columns=["Sentiment"])
df = df.rename(columns={"Majority_label": "Sentiment"})
df["Sentiment"].value_counts()
# Out:
# NEUTRAL     15328
# NEGATIVE    14846
# POSITIVE     1476
# Name: Sentiment, dtype: int64

# %%
# make date to datetime
df["Date_Tweet"] = pd.to_datetime(df["Date_Tweet"])
df["Date_Tweet"].describe()
# Out:
# count                         31650
# unique                        31304
# top       2022-10-11 07:17:28+00:00
# freq                              5
# first     2022-10-01 00:02:11+00:00
# last      2022-10-31 23:59:45+00:00
# Name: Date_Tweet, dtype: object

# %%
file = "stop_words_for_vis.txt"
with open(file, "r") as f:
    additional_stop_words = f.read().splitlines()


stopwords.extend(additional_stop_words)

# %%
df_neg = df[df["Sentiment"] == Sentiment.NEGATIVE.name]
df_pos = df[df["Sentiment"] == Sentiment.POSITIVE.name]
df_neu = df[df["Sentiment"] == Sentiment.NEUTRAL.name]

# %%
df_neg_count = df_neg.groupby(df.Date_Tweet.dt.date).count()["Tweet_Id"]
df_pos_count = df_pos.groupby(df.Date_Tweet.dt.date).count()["Tweet_Id"]

# max number of tweets per day
max_neg = df_neg_count.max()
max_pos = df_pos_count.max()

fig, host = plt.subplots(figsize=(15, 5))

par1 = host.twinx()

host.set_ylim(0, max_neg * 1.1)
par1.set_ylim(0, max_pos * 1.2)

host.set_xlabel("Date")
host.set_ylabel("-ve Tweets")
par1.set_ylabel("+ve Tweets")

# plot negative tweets
host.plot(df_neg_count, color="red", label="Negative")

# plot positive tweets
par1.plot(df_pos_count, color="green", label="Positive")

# plot max dotted line where the date is max
host.axvline(
    df_neg_count.idxmax(),
    linestyle="--",
    color="k",
    label=f"Max -ve tweets = {max_neg}",
)
par1.axvline(
    df_pos_count.idxmax(),
    linestyle="--",
    color="k",
    label=f"Max +ve tweets = {max_pos}",
)


# label the max line
host.text(
    df_neg_count.idxmax() - timedelta(days=1),
    max_neg + 50,
    df_neg_count.idxmax(),
    bbox=dict(boxstyle="square,pad=0.1", fc="white", ec="none"),
)
par1.text(
    df_pos_count.idxmax() - timedelta(days=1),
    max_pos + 5,
    df_pos_count.idxmax(),
    bbox=dict(boxstyle="square,pad=0.1", fc="white", ec="none"),
)

# lns = [p1, p2]
# host.legend(handles=lns, loc='best')
host.legend(loc="upper left")
par1.legend(loc="upper right")


# title
plt.title(f"Number of tweets per day in {MONTH} 2022")
plt.show()

# %%
df_pie = df[df["Sentiment"] != Sentiment.MIXED.name]

# labels
labels = df_pie["Sentiment"].value_counts().index.tolist()

# add in brackets the % of each sentiment with each label
labels = [
    f'{label} ({round(df_pie["Sentiment"].value_counts()[label]/len(df_pie)*100, 2)}%)'.capitalize()
    for label in labels
]

# colors from the color palette
colors = {
    Sentiment.NEUTRAL: "#7e6483",
    Sentiment.NEGATIVE: "#932790",
    Sentiment.POSITIVE: "#463f90",
}

plt.figure(figsize=(8, 8))
plt.pie(
    df_pie["Sentiment"].value_counts(),
    labels=labels,
    labeldistance=1.05,
    startangle=150,
    explode=(0.0, 0.0, 0.1),
    colors=colors.values(),
    wedgeprops=dict(width=0.5),
)
plt.title(f"Sentiment of tweets in {MONTH} 2022")
plt.show()

# %%
# wordcloud of negative tweets
wordcloud = WordCloud(
    stopwords=stopwords, background_color="white", width=1000, height=500
).generate(" ".join(df_neg["Tweet"].tolist()))

# recolor wordcloud and show
wordcloud.recolor(colormap="flare")

plt.figure(figsize=(15, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# wordcloud of positive tweets
wordcloud = WordCloud(
    stopwords=stopwords, background_color="white", width=1000, height=500
).generate(" ".join(df_pos["Tweet"].tolist()))

# recolor wordcloud and show
wordcloud.recolor(colormap="winter")

plt.figure(figsize=(15, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# wordcloud of neutral tweets
wordcloud = WordCloud(
    stopwords=stopwords, background_color="white", width=1000, height=500
).generate(" ".join(df_neu["Tweet"].tolist()))

# recolor wordcloud and show
wordcloud.recolor(colormap="copper")

plt.figure(figsize=(15, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# count number of words for negative tweets


def count_words(text):
    # split text into words
    words = word_tokenize(text)

    needed_words = []
    for word in words:
        word = word.lower()
        # continue if word is not punctuation
        if not word.isalpha():
            continue
        # check if word is in stopwords
        if word in stopwords:
            continue
        # add word to needed_words
        needed_words.append(word)
    return needed_words


counter_neg = Counter()
for index, row in df_neg.iterrows():
    counter_neg.update(count_words(row["Tweet"]))


counter_pos = Counter()
for index, row in df_pos.iterrows():
    counter_pos.update(count_words(row["Tweet"]))

counter_neu = Counter()
for index, row in df_neu.iterrows():
    counter_neu.update(count_words(row["Tweet"]))

# %%
top_50_neg = counter_neg.most_common(50)
top_50_pos = counter_pos.most_common(50)

# set of top 50 words for negative tweets
top_50_neg_set = set(word for word, _ in top_50_neg)
top_50_pos_set = set(word for word, _ in top_50_pos)

# mutually exclusive words
mutual_exclusive_neg = top_50_neg_set.difference(top_50_pos_set)
mutual_exclusive_pos = top_50_pos_set.difference(top_50_neg_set)

# common words
top_common_words = top_50_neg_set.intersection(top_50_pos_set)

# print
print(mutual_exclusive_neg)
print(mutual_exclusive_pos)
# Out:
# {'destroyed', 'ukrainianarmy', 'bridge', 'bomb', 'missiles', 'odessa', 'sanctions', 'lost', 'donetsk', 'attack', 'drones', 'killed', 'moscow', 'kyiv', 'missile', 'attacks', 'troops', 'illegal', 'destroy', 'russiaisaterroriststate', 'specialforces', 'says'}
# {'independent', 'freerussia', 'part', 'losing', 'lives', 'years', 'forward', 'demanding', 'nice', 'press', 'always', 'love', 'true', 'tanks', 'ones', 'elections', 'corruption', 'interest', 'believe', 'india', 'heroes', 'without'}

# %%
df_pos["Date_Tweet"].describe()
# Out:
# count                          1476
# unique                         1474
# top       2022-10-04 22:16:28+00:00
# freq                              2
# first     2022-10-01 00:11:59+00:00
# last      2022-10-31 23:24:17+00:00
# Name: Date_Tweet, dtype: object

# %%
# plot stacked bar chart of interesting words from each sentiment using counters
def plot_stacked_bar_chart(
    interesting_words,
    counter_neg,
    counter_pos,
    counter_neu,
    colors=colors,
    figsize=(15, 8),
):
    # create dataframe
    df = pd.DataFrame(
        {
            "word": interesting_words,
            "negative": [counter_neg[word] for word in interesting_words],
            "positive": [counter_pos[word] for word in interesting_words],
            "neutral": [counter_neu[word] for word in interesting_words],
        }
    )
    df["total"] = df["negative"] + df["positive"] + df["neutral"]
    # set index to word
    df = df.set_index("word")

    # calculate % of each sentiment for each word
    df["neg_percent"] = df["negative"] / df["total"]
    df["pos_percent"] = df["positive"] / df["total"]
    df["neu_percent"] = df["neutral"] / df["total"]

    # df.plot.bar(stacked=True, figsize=(15, 5))
    df[["neg_percent", "pos_percent", "neu_percent"]].plot.bar(
        stacked=True,
        figsize=figsize,
        color=[
            colors[Sentiment.NEGATIVE],
            colors[Sentiment.POSITIVE],
            colors[Sentiment.NEUTRAL],
        ],
    )

    # add the % on top of the bars
    for i, v in enumerate(df["neg_percent"]):
        plt.text(i, v / 2, f"{v:.0%}", color="white", fontweight="bold")
    for i, v in enumerate(df["pos_percent"]):
        plt.text(
            i,
            v / 2 + df["neg_percent"][i],
            f"{v:.0%}",
            color="white",
            fontweight="bold",
        )
    for i, v in enumerate(df["neu_percent"]):
        plt.text(
            i,
            v / 2 + df["neg_percent"][i] + df["pos_percent"][i],
            f"{v:.0%}",
            color="white",
            fontweight="bold",
        )

    # legend
    plt.legend(loc="best", labels=["Negative", "Positive", "Neutral"])
    plt.ylim(0, 1)
    plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    # make x axis labels horizontal
    plt.xticks(rotation=0)
    # title
    plt.title(f"Sentiment of tweets for words in {MONTH} 2022")
    plt.show()


interesting_words = "crimea kherson india energy elonmusk iran biden china kyiv".split()
# plot the stacked bar chart
plot_stacked_bar_chart(interesting_words, counter_neg, counter_pos, counter_neu)

# %%
interesting_words = "crimea kherson dnieper".split()
# plot the stacked bar chart
plot_stacked_bar_chart(
    interesting_words, counter_neg, counter_pos, counter_neu, figsize=(10, 5)
)

# %%
interesting_words = "india china".split()
# plot the stacked bar chart
plot_stacked_bar_chart(
    interesting_words, counter_neg, counter_pos, counter_neu, figsize=(6, 5)
)

# %%
interesting_words = "wage wages illegal".split()
# plot the stacked bar chart
plot_stacked_bar_chart(
    interesting_words, counter_neg, counter_pos, counter_neu, figsize=(6, 5)
)

# %%
# function to get top n-grams
# import countvectorizer
from sklearn.feature_extraction.text import CountVectorizer

# import tokenizer
from nltk.tokenize import word_tokenize
import string
import re

words_for_bigrams = "war putin nato usa sir sirs".split(" ")

# remove words from stop words
for w in words_for_bigrams:
    if w in stopwords:
        stopwords.remove(w)

# function to clean text
def clean_text(text):
    text = "".join([word.lower() for word in text if word not in string.punctuation])
    tokens = re.split("\W+", text)
    text = [word for word in tokens if word not in stopwords]
    return text


def get_top_n_ngram(corpus, ngram=2, n=None, stop_words=None):
    vec = CountVectorizer(
        ngram_range=(ngram, ngram), stop_words=stop_words, tokenizer=clean_text
    ).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
# top bigrams for negative tweets
top_bigrams_neg = get_top_n_ngram(
    df[df["Sentiment"] == Sentiment.NEGATIVE.name]["cleaned_text"].dropna(),
    ngram=2,
    n=20,
    stop_words=stopwords,
)

x, y = map(list, zip(*top_bigrams_neg))

# set color palette
# sns.set_palette(sns.color_palette("flare"))
plt.figure(figsize=(5, 5))
sns.barplot(x=y, y=x, palette=sns.color_palette("flare", 20))
plt.xlabel("Count")
plt.title(f"Top 20 bigrams for negative tweets ({MONTH[:3]} 2022)")
plt.show()

# %%
# top bigrams for positive tweets
top_bigrams_pos = get_top_n_ngram(
    df[df["Sentiment"] == Sentiment.POSITIVE.name]["cleaned_text"].dropna(),
    ngram=2,
    n=20,
    stop_words=stopwords,
)

x, y = map(list, zip(*top_bigrams_pos))

# set color palette
plt.figure(figsize=(5, 5))
sns.barplot(x=y, y=x, palette=sns.color_palette("winter", 20))
plt.xlabel("Count")
plt.title(f"Top 20 bigrams for positive tweets ({MONTH[:3]} 2022)")
plt.show()

# %%
# top bigrams for neutral tweets
top_bigrams_neu = get_top_n_ngram(
    df[df["Sentiment"] == Sentiment.NEUTRAL.name]["cleaned_text"].dropna(),
    ngram=2,
    n=20,
    stop_words=stopwords,
)

x, y = map(list, zip(*top_bigrams_neu))

# set color palette
plt.figure(figsize=(5, 5))
plt.xlabel("Count")
sns.barplot(x=y, y=x, palette=sns.color_palette("copper", 20))
plt.title(f"Top 20 bigrams for neutral tweets ({MONTH[:3]} 2022)")
plt.show()

# %%
# top trigrams for negative tweets
top_trigrams_neg = get_top_n_ngram(
    df[df["Sentiment"] == Sentiment.NEGATIVE.name]["cleaned_text"].dropna(),
    ngram=3,
    n=20,
    stop_words=stopwords,
)

x, y = map(list, zip(*top_trigrams_neg))

# set color palette
plt.figure(figsize=(5, 5))
sns.barplot(x=y, y=x, palette=sns.color_palette("flare", 20))
plt.xlabel("Count")
plt.title(f"Top 20 trigrams for negative tweets ({MONTH[:3]} 2022)")
plt.show()

# top trigrams for positive tweets
top_trigrams_pos = get_top_n_ngram(
    df[df["Sentiment"] == Sentiment.POSITIVE.name]["cleaned_text"].dropna(),
    ngram=3,
    n=20,
    stop_words=stopwords,
)

x, y = map(list, zip(*top_trigrams_pos))

# set color palette
plt.figure(figsize=(5, 5))
sns.barplot(x=y, y=x, palette=sns.color_palette("winter", 20))
plt.xlabel("Count")
plt.title(f"Top 20 trigrams for positive tweets ({MONTH[:3]} 2022)")
plt.show()

# %%
# top quadrigrams for negative tweets
top_quadrigrams_neg = get_top_n_ngram(
    df[df["Sentiment"] == Sentiment.NEGATIVE.name]["cleaned_text"].dropna(),
    ngram=4,
    n=20,
    stop_words=stopwords,
)

x, y = map(list, zip(*top_quadrigrams_neg))

# set color palette
plt.figure(figsize=(5, 5))
sns.barplot(x=y, y=x, palette=sns.color_palette("flare",20))
plt.xlabel("Count")
plt.title(f"Top 20 quadrigrams for negative tweets ({MONTH[:3]} 2022)")
plt.show()

# top quadrigrams for positive tweets
top_quadrigrams_pos = get_top_n_ngram(
    df[df["Sentiment"] == Sentiment.POSITIVE.name]["cleaned_text"].dropna(),
    ngram=4,
    n=20,
    stop_words=stopwords,
)

x, y = map(list, zip(*top_quadrigrams_pos))

# set color palette
plt.figure(figsize=(5, 5))
sns.barplot(x=y, y=x, palette=sns.color_palette("winter",20))
plt.xlabel("Count")
plt.title(f"Top 20 quadrigrams for positive tweets ({MONTH[:3]} 2022)")
plt.show()

# %%
# one tweet example for each sentiment containing the most common bigrams
for word in top_common_words:
    # print a positive tweet containing the word
    try:
        print(
            "Positive tweet containing the word '{}':".format(word),
            df[
                (df["Sentiment"] == Sentiment.POSITIVE.name)
                & (df["cleaned_text"].str.contains(word))
            ]["Tweet"].values[0],
        )
        print("-" * 100)
        print(
            "Negative tweet containing the word '{}':".format(word),
            df[
                (df["Sentiment"] == Sentiment.NEGATIVE.name)
                & (df["cleaned_text"].str.contains(word))
            ]["Tweet"].values[0],
        )
        print("=" * 100)
    except IndexError:
        pass
# Out:
# Positive tweet containing the word 'via': #Russia #Ukraine #Crimea #War #Donbass #SpecialMilitaryOperation
# Is Russia Poised To Win The Ukraine War? https://t.co/l060WcJPTy via @YouTube
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'via': So while engaging #Russia via #Ukraine, the #US is firing up war talk with Iran and provoking #China. Power-hungry sickos.
# ====================================================================================================
# Positive tweet containing the word 'uk': Is this a good idea?
#
# "These inspectors in Ukraine appear to be some of the first members of the U.S. military to re-enter the Eastern European country since the start of the war,"
#
# #Ukraine #Kyiv #Kherson #Donetsk #Crimea #Russia #NATO #POTUS
# https://t.co/8iMnt9LqMc
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'uk': What is striking is Ukraine wants this to be a more visual media war whereupon Russia want to hide their shortcomings. There are plenty.
#
# #Ukraine #UkraineWar #UkrainianArmy #UkraineRussiaWar #UkraineWillWin #Russia #Russian #RussianArmy #NAFO #BlackSeaGrainInitiative
# ====================================================================================================
# Positive tweet containing the word 'power': Powerful film by German Journalist and Filmaker Mark Bertalmia, who spent time in #Donbass and Ukraine documenting of the rise of Nazism in #Ukraine and the 8 year civil war. "Ukraine Agony" #denazifyukraine #Ukrainians #Russia #UkraineRussianWar
# https://t.co/0YxhowsoI7
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'power': #Ukraine is suffering from more missiles as it leads to power cuts and water shortages. People are at queue for drinking water. More consequences are on the way because of barbaric war initiated by #Putin #Russia.
# ====================================================================================================
# Positive tweet containing the word 'nuclear': I wonder if the people of the UK are okay with being dragged into a war, possibly nuclear, with Russia over Ukraine? Isn't the biggest story in the UK regarding the Ukraine the Ukrainian women refugees that become home wreckers? LOL #ukpoli #UK #Ukraine #Russia
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'nuclear': More than 8 months into a genocidal war by #Russia, the #EU still refuses to stop trading diamonds with this terrorist state. Which means they are willingly funding the 🇷🇺 nuclear arsenal. Seven billion EU annually in Putler's war chest.
#
# 👏 Diamond lobby puppet @alexanderdecroo https://t.co/7E8mKOLgvt
# ====================================================================================================
# Positive tweet containing the word 'countries': Interesting development where an #African leader calls for peaceful resolution for a war between Western countries.
#
# HE Umaro Sissoco Embaló is the man reversing the status quo.
#
# #Ukraine #Russia
# #RwOT https://t.co/4hJnyhI9Vj
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'countries': #Russia's unjustified, immoral war, is steadily seeping into neighbouring countries https://t.co/T30G5Li2Rv
# ====================================================================================================
# Positive tweet containing the word 'kherson': Life under Russian occupation, as told by my friend Yulia Scherbyna who spent the first months of the war in Russia-ruled Kherson.
#
# Proud to have provided her with a voice to tell her story with my colleagues on GB News #Ukraine #Russia #Kherson
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'kherson': Article Link: https://t.co/ijVGMOVupd
# Russian occupation authorities extend "evacuation" in Kherson Oblast
#
# Please Follow us to help the people of Ukraine
#
# #ukrainewar #ukraine #war #army #military  #specialforces #russia #nato #donetsk #soldiers #ukrainenews #odessa #ukrainian
# ====================================================================================================
# Positive tweet containing the word 'belarus': The train sabotage war is becoming swing in russia and belaruss. Great! Go on!#Bahkmut #kherson #Russia #RussianArmy #UkraineRussianWar
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'belarus': Article Link: https://t.co/6Tg9FpN7XI
# Russia and Belarus to create joint military training centres
#
# Please Follow us to help the people of Ukraine
#
# #ukrainewar #ukraine #war #army #military  #specialforces #russia #nato #donetsk #soldiers #ukrainenews #odessa #ukrainianarmy #lv
# ====================================================================================================
# Positive tweet containing the word 'civilians': #China’s officially informed of its #Russia support &amp; validates #UkraineWar, 💣 of hospitals &amp; schools, rapes of girls &amp; women,murders of civilians,slaughtered of all living being.I expected better from #China. Yes,I expected her to work for ☮️ not war @AmbassadeChine #XiJinping
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'civilians': @casan0vacrypto @OrangeMarkD @Crs_Rumcajs @SamRamani2 You seem to be confused - only #Russia is currently carrying out war crimes at a scale not seen since Nazi Germany in WWII.
#
# Are you a fan of invasion, murder, rape, torture of civilians? Genocide?
#
# I suspect you may be a #Vatnik 🤷‍♀️#russiaisaterrorisstate https://t.co/Yixtik6S0K
# ====================================================================================================
# Positive tweet containing the word 'china': THE CHINA THREAT? Good example?
# "We produce #statesmen. They produce #politicians."
# Xi Jinping gets 3rd term
# https://t.co/GbkaPBIUv2
# #XiJinping #FZGPS #WION #Tucker #war #peace #Russia #China #India #NDTV #Germany #England #Asia #Europe https://t.co/FA0NmiJQ74
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'china': "#Russia has lost all #credibility, is a #liar &amp; has earned the #disrespect &amp; #contempt of the whole world. Even China. No country on earth needs permission from Russia to ship food along routes agreed by the UN. . All out war. 5:48 PM Oct 31, 2022 ·", by Jo @JoCoconutOil  $SPY
# ====================================================================================================
# Positive tweet containing the word 'weapons': Western weapons are turning the tide in the war in #Ukraine #Russia has lost it best troops, pilots  and equipment and is turning to untrained troops, 60 year old tanks &amp; guns. Plus whatever they can scrounge from #Iran &amp; #Belarus. #UkraineRussiaWar
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'weapons': Diplomacy not weapons!
# Diplomacy not Properganda!
# Peace not War!
# #Russia #USA #EU #UK
# @POTUS
# @KremlinRussia_C
# Using up out of date ordnance Laundering &amp; funneling money via #UkraineUnderAttack
# Shamefully abusing &amp; killing innocent people!
# #Diplomacyworks
#
# https://t.co/4hTo9buCfU
# ====================================================================================================
# Positive tweet containing the word 'eu': Is this a good idea?
#
# "These inspectors in Ukraine appear to be some of the first members of the U.S. military to re-enter the Eastern European country since the start of the war,"
#
# #Ukraine #Kyiv #Kherson #Donetsk #Crimea #Russia #NATO #POTUS
# https://t.co/8iMnt9LqMc
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'eu': What is striking is Ukraine wants this to be a more visual media war whereupon Russia want to hide their shortcomings. There are plenty.
#
# #Ukraine #UkraineWar #UkrainianArmy #UkraineRussiaWar #UkraineWillWin #Russia #Russian #RussianArmy #NAFO #BlackSeaGrainInitiative
# ====================================================================================================
# Positive tweet containing the word 'europe': Is this a good idea?
#
# "These inspectors in Ukraine appear to be some of the first members of the U.S. military to re-enter the Eastern European country since the start of the war,"
#
# #Ukraine #Kyiv #Kherson #Donetsk #Crimea #Russia #NATO #POTUS
# https://t.co/8iMnt9LqMc
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'europe': There is a major war in modern Europe today, and #Biden &amp; #Democrats are focused on killing the unborn. #europe #russia #putin #moscow #Ukraine #pariahPutin #NoUSleadership #cackles #senile #pudding #naps #DroolerInChief #abortElection
# ====================================================================================================
# Positive tweet containing the word 'peace': if you are the #president, you wanted #peace for your country that is suffering from a #war and a LEADER of a peaceful country told you to abandoned the peace and go for #war and you agreed, what type of president does that makes YOU? #peace&amp;love #Ukraine #zelensky #russia
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'peace': @JonMaloy @MintPressNews It's nuts to think #Russia wants an expanded war involving #NATO.  Their efforts to negotiate a peace deal were blocked by the #Biden administration which wants regime change; Biden himself stated that #Putin "cannot remain in power."   And there's this:
# https://t.co/julnANdwol
# ====================================================================================================
# Positive tweet containing the word 'country': Is this a good idea?
#
# "These inspectors in Ukraine appear to be some of the first members of the U.S. military to re-enter the Eastern European country since the start of the war,"
#
# #Ukraine #Kyiv #Kherson #Donetsk #Crimea #Russia #NATO #POTUS
# https://t.co/8iMnt9LqMc
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'country': @steve_hanke When did Zelensky start a war????  It is RUSSIA’s invasion of a free and democratic country that started the war.  Better yet, why don’t you STHU especially when you know zip about this war…armchair quarterbacking at its worst! 🤬 #RussiaIsLosing #russiaisateroriststate #Russia
# ====================================================================================================
# Positive tweet containing the word 'free': @kpru Dear sirs, indeed the true #Russian heroes are the ones refusing to fight in or support #Putin's war, demanding free elections in #Russia, fighting corruption, demanding free press, demanding independent judges &amp; honest police. #FreeRussia. We love RU-people, we hate #Putin's war
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'free': @steve_hanke When did Zelensky start a war????  It is RUSSIA’s invasion of a free and democratic country that started the war.  Better yet, why don’t you STHU especially when you know zip about this war…armchair quarterbacking at its worst! 🤬 #RussiaIsLosing #russiaisateroriststate #Russia
# ====================================================================================================
# Positive tweet containing the word 'western': #Putin is counting on collapse of #Europe &amp; #US support for #War in #Ukraine in order for #Russia to win.
#
# Consequently Western #Allies must redouble their commitment to #Ukraine #Support. #US #Democratic majorities will ensure it.
# #Philadelphia #Pittsburgh #Harrisburg #Scranton
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'western': #Ukraine mainly exported grain to rich countries so it can cash the revenues that lift some burden on the western countries who are responsible for the continuity of the war.
# Price of food and energy is rising in Europe since our leaders imposed sanctions on #Russia.
# ====================================================================================================
# Positive tweet containing the word 'iran': The last stake of Great #Russia in its war against Ukraine is the mercenaries of Afghanistan, the miracle weapon of Iran and the diplomacy of Guinea-Bissau.
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'iran': #Zelensky. For every ten hits, terrorists (#Russia) have to spend at least four more missiles. Russia has an even worse record with regard to drones, including those supplied by its Iranian partners #War_in_Ukraine https://t.co/gtNvAcauSb
# ====================================================================================================
# Positive tweet containing the word 'america': «The war in Ukraine has a great deal to do with the American intention to push NATO into Ukraine, and across the Black Sea, into Georgia. This is a narrative that the US doesn't want the people to know, but it's reality." — Professor Jeffrey Sachs
#
# #US #USA #Ukraine #Russia https://t.co/UdsQQqbkvl
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'america': #Russia's war on #Ukraine is undergirded by pseudo-intellectual academics espousing pro-#Kremlin ideas and a radical rejection of today's #liberalworld. American Purpose https://t.co/tnoKYLj16r
# ====================================================================================================
# Positive tweet containing the word 'proxy': Gabriel Boric, the superb pseudo-leftist honest friend of Zelensky the persecutor of leftists with fans of Pinochet in #Ukraine for being too "pro" #Russia —celebrating with the creators of the proxy war the triumph of Lula. Ay! “hermano” wipe your mouth! 🤣😂😂 “Alegría” 71%
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'proxy': "Is NATO Fighting a Proxy War?" @DrShea_DC
# asks Foreign Minister Péter Szijjártó.
#
# #Ukraine #UkraineRussianWar #RussiaUkraineWar #USA #Russia #Hungary #Peace #CounterpointDC https://t.co/GFVTOk63Sx
# ====================================================================================================
# Positive tweet containing the word 'crimea': @mfa_russia @RussiaUN @mission_russian @RF_OSCE @mission_rf @RusMission_EU @EUinRussia @natomission_ru @NATOpress @RusBotschaft @AmbRusFrance Russia has killed more Ukranian civilians than Adolf Hitler did in the Great Patriotic War.  Leave Ukraine and Crimea while you still can.  Then Ukraine will talk peace #Ukraine #Crimea #Russia #Iran #India #hungary https://t.co/oQDrLVUohF
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'crimea': In #Kyiv, queues for water have become lifelong. Now every resident of Kiev has caught how people lived in the Donbass and Crimea without water.
#
# #UkraineRussianWar #Ukraine #Russia #War https://t.co/TOaBAxrdqX
# ====================================================================================================
# Positive tweet containing the word 'west': #Putin is counting on collapse of #Europe &amp; #US support for #War in #Ukraine in order for #Russia to win.
#
# Consequently Western #Allies must redouble their commitment to #Ukraine #Support. #US #Democratic majorities will ensure it.
# #Philadelphia #Pittsburgh #Harrisburg #Scranton
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'west': #Ukraine mainly exported grain to rich countries so it can cash the revenues that lift some burden on the western countries who are responsible for the continuity of the war.
# Price of food and energy is rising in Europe since our leaders imposed sanctions on #Russia.
# ====================================================================================================
# Positive tweet containing the word 'forces': Here’s how good Ukrainian armed forces are: they precision struck 5 Russian mobile artillery guns all at once plus 2 ammunition trucks. That’s LETHAL FORCE Ukraine Style 🇺🇦
# They find them &amp; they hit them so hard they’re blown apart. #Russia could end this war by leaving tomorrow
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'forces': @steve_hanke It's very interesting how #German right-wing anti-EU forces, including neo-#nazis, funded by #Russia for decades, are all suddenly pacifists demonstrating against the #war. These degraded mental ruins of the 3rd #reich, including @steve_hanke, are the shameful worth of Germany.
# ====================================================================================================
# Positive tweet containing the word 'biden': Biden continues to run the US into the ground. He is a delight to #Iran, #china #russia #Xi #putin #biden #failure #loser #DemocratsAreDestroyingAmerica #DemocratsAreTheProblem #inflation #crime #war #taxes #lies
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'biden': Biden failures- #abortion #border #invaders #ILLEGALimmigrants #china #war #europe #russia #oil #Inflation #college #debt #taxes #pot #deficit #europe #ukraine #crime #budget #senile #drooling  #DemocratsAreTheProblem #BidenWorstPresidentEver
# ====================================================================================================
# Positive tweet containing the word 'zelensky': Gabriel Boric, the superb pseudo-leftist honest friend of Zelensky the persecutor of leftists with fans of Pinochet in #Ukraine for being too "pro" #Russia —celebrating with the creators of the proxy war the triumph of Lula. Ay! “hermano” wipe your mouth! 🤣😂😂 “Alegría” 71%
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'zelensky': @steve_hanke When did Zelensky start a war????  It is RUSSIA’s invasion of a free and democratic country that started the war.  Better yet, why don’t you STHU especially when you know zip about this war…armchair quarterbacking at its worst! 🤬 #RussiaIsLosing #russiaisateroriststate #Russia
# ====================================================================================================
# Positive tweet containing the word 'president': @TiborPNagyJr #Ukraine president Mr. @ZelenskyyUa should take full responsibility for z devastation of #Ukraine ? If he was wise he would have been sat&amp; frankly discuss with #Russia&amp; saved #Ukraine.
# Now #USA took z conflict as good opportunity to weaken #Russia. Hereafter z war is b/t 🇺🇸&amp;🇷🇺
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'president': #Lula blames #Ukraine's president for the war and supports #Putin's narrative. Why do international actors think that there will be such big changes with a left-wing candidate who supports #Russia's regime? #RussiaIsATerroristState #Kherson #Brazil #Kherson https://t.co/kC1tQqRMEF
# ====================================================================================================
# Positive tweet containing the word 'crimes': @RussianEmbassy @mfa_russia @RussiaUN @EmbassyofRussia @FCDOGovUK @10DowningStreet @DefenceHQ @BBCWorld @bbcrussian @Telegraph @guardian #Russia should better be concerned about their war crimes in Ukraine and about the price it will continue to pay for it for a very long time in the future. Many Russians will look back on #Putin as the guy that turned Russia into a failed state.
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'crimes': Some information compiled by (Emma Beals) on the massacres, war crimes and atrocities committed by Assad the criminal and others who have helped him in these crimes #Russia #Iran #Syria
# ====================================================================================================
# Positive tweet containing the word 'energy': Seeing the silver lining on a very dark cloud. "In its annual World Energy Outlook, the International #energy  Agency #IAE couldn’t be clearer: #Russia’s war in #Ukraine has changed the landscape for good" https://t.co/K0Wv0v8J8t via @opinion
# ----------------------------------------------------------------------------------------------------
# Negative tweet containing the word 'energy': @POTUS We have a Pres &amp; Dem party that:
# - gave control of our economy to #Russia, #Iran, #Saudi &amp; #Venezuela
# - gave control of our border to the Mexican Drug #Cartel
# - failed energy policy &amp; resulting price increases is funding Russia in it war w Ukraine, while taxpayer fund #Ukraine
# ====================================================================================================
