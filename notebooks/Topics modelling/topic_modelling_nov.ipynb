# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore")

# %%
df_nov=pd.read_csv('/content/Final__nov_result.csv')

# %%
df_nov.head(3)
# Out:
#            User               Date_Created  Follows_Count  Friends_Count  \
# 0     mic_marek  2018-11-10 14:01:32+00:00          12228            830
# 1  10WallStreet  2012-08-26 19:26:27+00:00           1108            607
# 2  onsaledrones  2020-05-07 19:01:27+00:00            130              9
#
#    Retweet_Count Language                 Date_Tweet  Number_of_Likes  \
# 0              0       en  2022-11-27 19:20:18+00:00                0
# 1              1       en  2022-11-27 19:16:01+00:00                1
# 2              0       en  2022-11-27 19:15:35+00:00                0
#
#        Source_of_Tweet             Tweet_Id  ...  \
# 0      Twitter Web App  1596947040432709633  ...
# 1  Twitter for Android  1596945959065645056  ...
# 2              dlvr.it  1596945849929863168  ...
#
#                         In_reply_To Coordinates  Place  \
# 0                               NaN         NaN    NaN
# 1  https://twitter.com/10WallStreet         NaN    NaN
# ...

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from collections import  Counter

# %%
from sklearn.decomposition import LatentDirichletAllocation
vectorizer = CountVectorizer(
analyzer='word',       
min_df=3,# minimum required occurences of a word 
stop_words='english',# remove stop words
lowercase=True,# convert all words to lowercase
token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
max_features=5000,# max number of unique words
                            )
data_matrix = vectorizer.fit_transform(df_nov.cleaned_text) # passing te cleaned text to vectorizer
data_matrix
# Out:
# <28575x5000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 253444 stored elements in Compressed Sparse Row format>

# %%
# I will use LDA to create topics along with the probability distribution for each word in our vocabulary for each topic
lda_model = LatentDirichletAllocation(
n_components=5, # Number of topics
learning_method='online',
random_state=20,       
n_jobs = -1  # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_matrix)

# %%
# !pip install pyLDAvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pyLDAvis
import pyLDAvis.sklearn
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

#pyLDAvis extracts information from a fitted LDA topic model to inform an interactive web-based visualization
pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda_model, data_matrix, vectorizer, mds='tsne')
# Out:
# /usr/local/lib/python3.8/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import Iterable
# /usr/local/lib/python3.8/dist-packages/past/builtins/misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import Mapping
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %% [markdown]
# ## Drawing topics from Negative tweets

# %% [markdown]
# Majority_label

# %%
df_nov_neg=df_nov[df_nov['Majority_label']=='NEGATIVE']

# %% [markdown]
# ### With monogram

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)
vectorizer = CountVectorizer(
analyzer='word', ngram_range=(1,1)  ,   
min_df=3,# minimum required occurences of a word 
stop_words='english',# remove stop words
lowercase=True,# convert all words to lowercase
token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
max_features=5000,# max number of unique words
                            )
data_matrix = vectorizer.fit_transform(df_nov_neg.cleaned_text) # passing te cleaned text to vectorizer


# I will use LDA to create topics along with the probability distribution for each word in our vocabulary for each topic
lda_model = LatentDirichletAllocation(
n_components=5, # Number of topics
learning_method='online',
random_state=20,       
n_jobs = -1  # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_matrix)

#pyLDAvis extracts information from a fitted LDA topic model to inform an interactive web-based visualization
pyLDAvis.sklearn.prepare(lda_model, data_matrix, vectorizer, mds='tsne')
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# ...

# %%
#  top 10 most frequent words from each topic that found by LDA
warnings.filterwarnings("ignore", category=DeprecationWarning)
for i,topic in enumerate(lda_model.components_):
    print('Top 10 words for topic:',i)
    print([vectorizer.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic: 0
# ['latest', 'ukrainians', 'missiles', 'poland', 'attack', 'today', 'russian', 'russia', 'missile', 'ukraine']
#
#
# Top 10 words for topic: 1
# ['soldiers', 'kherson', 'troops', 'drone', 'forces', 'footage', 'war', 'ukrainian', 'russian', 'ukraine']
#
#
# Top 10 words for topic: 2
# ['update', 'news', 'day', 'russian', 'russias', 'kherson', 'putin', 'russia', 'ukraine', 'war']
#
#
# Top 10 words for topic: 3
# ['infrastructure', 'energy', 'civilians', 'crimes', 'power', 'military', 'link', 'follow', 'help', 'war']
#
#
# Top 10 words for topic: 4
# ['west', 'stop', 'weapons', 'said', 'end', 'russia', 'article', 'world', 'people', 'war']
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### with bigram

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)
vectorizer = CountVectorizer(
analyzer='word', ngram_range=(2,2)  ,   
min_df=3,# minimum required occurences of a word 
stop_words='english',# remove stop words
lowercase=True,# convert all words to lowercase
token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
max_features=5000,# max number of unique words
                            )
data_matrix = vectorizer.fit_transform(df_nov_neg.cleaned_text) # passing te cleaned text to vectorizer


# I will use LDA to create topics along with the probability distribution for each word in our vocabulary for each topic
lda_model = LatentDirichletAllocation(
n_components=5, # Number of topics
learning_method='online',
random_state=20,       
n_jobs = -1  # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_matrix)

#pyLDAvis extracts information from a fitted LDA topic model to inform an interactive web-based visualization
pyLDAvis.sklearn.prepare(lda_model, data_matrix, vectorizer, mds='tsne')
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# ...

# %%
#  top 10 most frequent words from each topic that found by LDA
warnings.filterwarnings("ignore", category=DeprecationWarning)
for i,topic in enumerate(lda_model.components_):
    print('Top 10 words for topic:',i)
    print([vectorizer.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic: 0
# ['war ukraine', 'russian forces', 'proxy war', 'tensions today', 'russia tensions', 'combat footage', 'war russia', 'ukraine russia', 'russia war', 'ukraine war']
#
#
# Top 10 words for topic: 1
# ['footage ukraine', 'ukrainian forces', 'footage ukrainian', 'ukraine explained', 'destroy russian', 'ukraine drone', 'russian troops', 'russian soldiers', 'drone footage', 'war ukraine']
#
#
# Top 10 words for topic: 2
# ['war map', 'war russian', 'bbc news', 'war update', 'war live', 'russiaukraine war', 'world war', 'russia ukraine', 'war footage', 'ukraine war']
#
#
# Top 10 words for topic: 3
# ['russian army', 'forces ukraine', 'russias war', 'update ukraine', 'ukrainian troops', 'armed forces', 'follow help', 'article link', 'help people', 'people ukraine']
#
#
# Top 10 words for topic: 4
# ['started war', 'dear sirs', 'north korea', 'russian war', 'war criminals', 'stop war', 'ukrainian military', 'nuclear war', 'war ukraine', 'war crimes']
# ...

# %% [markdown]
# ### with trigram

# %%
vectorizer = CountVectorizer(
analyzer='word', ngram_range=(3,3)  ,   
min_df=3,# minimum required occurences of a word 
stop_words='english',# remove stop words
lowercase=True,# convert all words to lowercase
token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
max_features=5000,# max number of unique words
                            )
data_matrix = vectorizer.fit_transform(df_nov_neg.cleaned_text) # passing te cleaned text to vectorizer


# I will use LDA to create topics along with the probability distribution for each word in our vocabulary for each topic
lda_model = LatentDirichletAllocation(
n_components=5, # Number of topics
learning_method='online',
random_state=20,       
n_jobs = -1  # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_matrix)

#pyLDAvis extracts information from a fitted LDA topic model to inform an interactive web-based visualization
pyLDAvis.sklearn.prepare(lda_model, data_matrix, vectorizer, mds='tsne')
# Out:
# /usr/local/lib/python3.8/dist-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# ...

# %%
#  top 10 most frequent words from each topic that found by LDA
warnings.filterwarnings("ignore", category=DeprecationWarning)
for i,topic in enumerate(lda_model.components_):
    print('Top 10 words for topic:',i)
    print([vectorizer.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic: 0
# ['ukraine combat footage', 'footage ukraine drone', 'drone drops grenade', 'war footage ukrainian', 'ukraine drone attack', 'news enforcer day', 'current ukraine war', 'ukraine russia war', 'war footage ukraine', 'ukraine war footage']
#
#
# Top 10 words for topic: 1
# ['footage ukrainian troops', 'combat footage sniper', 'footage sniper reviews', 'war video footage', 'ukraine war combat', 'war combat footage', 'ukraine war ukrainian', 'ukraine war map', 'russia tensions today', 'russia ukraine war']
#
#
# Top 10 words for topic: 2
# ['ukraine follow help', 'update ukraine ruzzia', 'black sea fleet', 'article link russians', 'russian invasion ukraine', 'article link ukrainian', 'oblast follow help', 'article link russian', 'help people ukraine', 'follow help people']
#
#
# Top 10 words for topic: 3
# ...

# %% [markdown]
# # Topics Modelling from positive tweets

# %%
df_nov_pos=df_nov[df_nov['Majority_label']=='POSITIVE']
df_nov_pos.shape
# Out:
# (1743, 23)

# %% [markdown]
# ### Monogram

# %%
vectorizer = CountVectorizer(
analyzer='word', ngram_range=(1,1)  ,   
min_df=3,# minimum required occurences of a word 
stop_words='english',# remove stop words
lowercase=True,# convert all words to lowercase
token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
max_features=5000,# max number of unique words
                            )
data_matrix = vectorizer.fit_transform(df_nov_pos.cleaned_text) # passing te cleaned text to vectorizer


# I will use LDA to create topics along with the probability distribution for each word in our vocabulary for each topic
lda_model = LatentDirichletAllocation(
n_components=5, # Number of topics
learning_method='online',
random_state=20,       
n_jobs = -1  # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_matrix)

#pyLDAvis extracts information from a fitted LDA topic model to inform an interactive web-based visualization
pyLDAvis.sklearn.prepare(lda_model, data_matrix, vectorizer, mds='tsne')
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# ...

# %%
#  top 10 most frequent words from each topic that found by LDA
warnings.filterwarnings("ignore", category=DeprecationWarning)
for i,topic in enumerate(lda_model.components_):
    print('Top 10 words for topic:',i)
    print([vectorizer.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic: 0
# ['going', 'country', 'putin', 'world', 'ukraine', 'russia', 'great', 'good', 'win', 'war']
#
#
# Top 10 words for topic: 1
# ['link', 'follow', 'best', 'peace', 'russian', 'russia', 'help', 'people', 'ukraine', 'war']
#
#
# Top 10 words for topic: 2
# ['said', 'russia', 'news', 'new', 'ukrainian', 'good', 'russian', 'peace', 'ukraine', 'war']
#
#
# Top 10 words for topic: 3
# ['true', 'support', 'elections', 'stop', 'sirs', 'dear', 'love', 'demanding', 'free', 'war']
#
#
# Top 10 words for topic: 4
# ['like', 'natural', 'total', 'ukrainians', 'germany', 'storage', 'gas', 'want', 'level', 'war']
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Bigram

# %%
vectorizer = CountVectorizer(
analyzer='word', ngram_range=(2,2)  ,   
min_df=3,# minimum required occurences of a word 
stop_words='english',# remove stop words
lowercase=True,# convert all words to lowercase
token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
max_features=5000,# max number of unique words
                            )
data_matrix = vectorizer.fit_transform(df_nov_pos.cleaned_text) # passing te cleaned text to vectorizer


# I will use LDA to create topics along with the probability distribution for each word in our vocabulary for each topic
lda_model = LatentDirichletAllocation(
n_components=5, # Number of topics
learning_method='online',
random_state=20,       
n_jobs = -1  # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_matrix)

#pyLDAvis extracts information from a fitted LDA topic model to inform an interactive web-based visualization
pyLDAvis.sklearn.prepare(lda_model, data_matrix, vectorizer, mds='tsne')
# Out:
# /usr/local/lib/python3.8/dist-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# ...

# %%
#  top 10 most frequent words from each topic that found by LDA
warnings.filterwarnings("ignore", category=DeprecationWarning)
for i,topic in enumerate(lda_model.components_):
    print('Top 10 words for topic:',i)
    print([vectorizer.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic: 0
# ['russia war', 'ending war', 'war started', 'war footage', 'level germany', 'total natural', 'gas storage', 'natural gas', 'storage level', 'ukraine war']
#
#
# Top 10 words for topic: 1
# ['lives soldiers', 'military morally', 'completely humiliating', 'humiliating military', 'dear sirs', 'war russia', 'stop war', 'war crimes', 'started war', 'win war']
#
#
# Top 10 words for topic: 2
# ['neighbour country', 'invaded neighbour', 'civilians hospitals', 'supporting war', 'war dump', 'dump free', 'peace talks', 'dear sirs', 'free elections', 'stop war']
#
#
# Top 10 words for topic: 3
# ['peace war', 'make peace', 'civil war', 'special military', 'war good', 'looks like', 'nuclear war', 'proxy war', 'world war', 'war ukraine']
#
#
# Top 10 words for topic: 4
# ['help people', 'people ukraine', 'support war', 'rupeople hate', 'love rupeople', 'hate war', 'dear sirs', 'free elections', 'free press', 'demanding free']
# ...

# %% [markdown]
# ### Trigram

# %%
vectorizer = CountVectorizer(
analyzer='word', ngram_range=(3,3)  ,   
min_df=3,# minimum required occurences of a word 
stop_words='english',# remove stop words
lowercase=True,# convert all words to lowercase
token_pattern='[a-zA-Z0-9]{3,}',# num chars > 3
max_features=5000,# max number of unique words
                            )
data_matrix = vectorizer.fit_transform(df_nov_pos.cleaned_text) # passing te cleaned text to vectorizer


# I will use LDA to create topics along with the probability distribution for each word in our vocabulary for each topic
lda_model = LatentDirichletAllocation(
n_components=5, # Number of topics
learning_method='online',
random_state=20,       
n_jobs = -1  # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_matrix)

#pyLDAvis extracts information from a fitted LDA topic model to inform an interactive web-based visualization
pyLDAvis.sklearn.prepare(lda_model, data_matrix, vectorizer, mds='tsne')
# Out:
# /usr/local/lib/python3.8/dist-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# ...

# %%
#  top 10 most frequent words from each topic that found by LDA
warnings.filterwarnings("ignore", category=DeprecationWarning)
for i,topic in enumerate(lda_model.components_):
    print('Top 10 words for topic:',i)
    print([vectorizer.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic: 0
# ['germany development storage', 'development storage level', 'level germany development', 'plan win war', 'ukraines plan win', 'world war iii', 'storage level germany', 'gas storage level', 'total natural gas', 'natural gas storage']
#
#
# Top 10 words for topic: 1
# ['fighting corruption demanding', 'demanding free press', 'demanding free elections', 'judges honest police', 'police love rupeople', 'war demanding free', 'independent judges honest', 'corruption demanding free', 'rupeople hate war', 'love rupeople hate']
#
#
# Top 10 words for topic: 2
# ['ukrainian landukraine war', 'article link russian', 'russian occupiers best', 'best fertilizer ukrainian', 'occupiers best fertilizer', 'great patriotic war', 'special military operation', 'article link zelenskyy', 'follow help people', 'help people ukraine']
#
#
# Top 10 words for topic: 3
# ...
