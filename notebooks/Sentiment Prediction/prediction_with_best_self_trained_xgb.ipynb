# %% [markdown]
# Import All necessary modules

# %%
import time
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split, KFold, cross_validate
from xgboost import XGBClassifier
from sklearn.metrics import f1_score, accuracy_score

#import deepcopy
from copy import deepcopy

import nltk
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
df = pd.read_csv("sentiment_analysis.csv")

# %%
df.shape
# Out:
# (550391, 3)

# %%
df.head(2)
# Out:
#              ID                                               text  label
# 0  7.680980e+17  Josh Jenkins is looking forward to TAB Breeder...      1
# 1  7.680980e+17  RT @MianUsmanJaved: Congratulations Pakistan o...      1

# %% [markdown]
# #Preprocessing  Data

# %% [markdown]
# convert everything to lower case

# %%
df['lower']=df['text'].str.lower()

# %% [markdown]
# remove HTML, Hashtags, Mentions, Digits, and Emojis

# %%
import re
# using the 're.sub' to remove urls.
def remove_urls(text):
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"www.(\w+)", "", text)
    return text
# calling function to remove all urls
df["cleaned_text"]=df["lower"].apply(remove_urls)

# %% [markdown]
#  Remove HTML entities

# %%
df['cleaned_text']=df['cleaned_text'].str.replace("&amp","")

# %% [markdown]
# remove stop words

# %%
# import nltk package to find stopwords
import nltk
from nltk.corpus import stopwords  
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Remove Punctuations

# %%
# using the 're.sub' to remove punctuation.
import re
def remove_punctuation(text):
    text = re.sub(r"[^\w\s]", "", text)
    return text
df["cleaned_text"] = df["cleaned_text"].apply(remove_punctuation)

# %% [markdown]
# remove numbers

# %%
def removing_numbers(text):
    return re.sub('[0-9]+', '', text)
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: removing_numbers(x))

# %% [markdown]
# Tokenize the data

# %%
import nltk
nltk.download('punkt')
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#              ID                                               text  label  \
# 0  7.680980e+17  Josh Jenkins is looking forward to TAB Breeder...      1
# 1  7.680980e+17  RT @MianUsmanJaved: Congratulations Pakistan o...      1
# 2  7.680980e+17  RT @PEPalerts: This September, @YESmag is taki...      1
# 3  7.680980e+17  RT @david_gaibis: Newly painted walls, thanks ...      1
# 4  7.680980e+17  RT @CedricFeschotte: Excited to announce: as o...      1
#
#                                                lower  \
# 0  josh jenkins is looking forward to tab breeder...
# 1  rt @mianusmanjaved: congratulations pakistan o...
# 2  rt @pepalerts: this september, @yesmag is taki...
# 3  rt @david_gaibis: newly painted walls, thanks ...
# 4  rt @cedricfeschotte: excited to announce: as o...
#
#                                         cleaned_text
# 0  [josh, jenkins, looking, forward, tab, breeder...
# 1  [rt, mianusmanjaved, congratulations, pakistan...
# 2  [rt, pepalerts, september, yesmag, taking, mai...
# 3  [rt, david_gaibis, newly, painted, walls, than...
# 4  [rt, cedricfeschotte, excited, announce, july,...

# %% [markdown]
# Lemmatization of tokens

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
df['cleaned_text'].head()
# Out:
# 0    [josh, jenkins, looking, forward, tab, breeder...
# 1    [rt, mianusmanjaved, congratulation, pakistan,...
# 2    [rt, pepalerts, september, yesmag, taking, mai...
# 3    [rt, david_gaibis, newly, painted, wall, thank...
# 4    [rt, cedricfeschotte, excited, announce, july,...
# Name: cleaned_text, dtype: object

# %% [markdown]
# Stemming of tokens

# %%
stemmer = nltk.stem.SnowballStemmer('english')
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: [stemmer.stem(word) for word in x])
df['cleaned_text'].head()
# Out:
# 0    [josh, jenkin, look, forward, tab, breeder, cr...
# 1    [rt, mianusmanjav, congratul, pakistan, becom,...
# 2    [rt, pepalert, septemb, yesmag, take, main, me...
# 3    [rt, david_gaibi, newli, paint, wall, thank, m...
# 4    [rt, cedricfeschott, excit, announc, juli, fes...
# Name: cleaned_text, dtype: object

# %% [markdown]
# Update the text column

# %%
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: " ".join(x))
df['cleaned_text'].head()
# Out:
# 0    josh jenkin look forward tab breeder crown sup...
# 1    rt mianusmanjav congratul pakistan becom notes...
# 2    rt pepalert septemb yesmag take main mendoza s...
# 3    rt david_gaibi newli paint wall thank million ...
# 4    rt cedricfeschott excit announc juli feschott ...
# Name: cleaned_text, dtype: object

# %% [markdown]
# ## feature extraction with TF_IDF vectorizer

# %%
## Tuned parameters
scale_pos_weight=df['label'].value_counts()[0]/df['label'].value_counts()[1]
# best computational cost to score ratio is at 10000 for xgboost
max_features = 10000
param_grid = {
    'max_depth' : 25,
    'n_estimators' : 100,
    'min_child_weight': 3,
    'subsample' : 0.5,
    'scale_pos_weight' : scale_pos_weight
}

# %%
vectorizer = TfidfVectorizer(max_features = max_features)
X = vectorizer.fit_transform(df['cleaned_text'])
y = df['label']

# %% [markdown]
# # Training

# %%
xgb = XGBClassifier(**param_grid)
xgb.fit(X, y)
# Out:
# XGBClassifier(max_depth=25, min_child_weight=3,
#               scale_pos_weight=0.482171373481517, subsample=0.5)

# %%
print('Accuracy: ', accuracy_score(y, y_pred))
print('F1 Score: ', f1_score(y, y_pred))
# Out:
# Accuracy:  0.9308818639839678
# F1 Score:  0.9469351202963889

# %% [markdown]
# #Prediction

# %%
df_test=pd.read_csv('/content/aws_vader_textblob_oct_result.csv')

# %%
df_test
# Out:
#                   User               Date_Created  Follows_Count  \
# 0           Europaetal  2022-03-22 21:23:26+00:00             31
# 1             marra_ua  2022-08-08 11:41:38+00:00             44
# 2        Starbright489  2019-07-27 03:10:29+00:00            211
# 3       geopol_monitor  2013-08-22 09:51:47+00:00           2998
# 4               PCiesa  2021-01-07 01:13:39+00:00             16
# ...                ...                        ...            ...
# 32647         paroliro  2022-09-12 14:14:38+00:00             11
# 32648          tvmario  2009-09-02 15:23:29+00:00           2408
# 32649  Writing_Destiny  2009-04-28 10:18:39+00:00           2704
# 32650    besthealthyou  2013-07-06 19:54:34+00:00            450
# 32651   Suspended_Acct  2012-09-20 15:20:09+00:00           6777
#
#        Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                 56              0       en  2022-10-31 23:59:45+00:00
# 1                  5              1       en  2022-10-31 23:57:36+00:00
# 2               3265              0       en  2022-10-31 23:49:24+00:00
# 3                315              0       en  2022-10-31 23:49:18+00:00
# 4                210              0       en  2022-10-31 23:46:43+00:00
# ...              ...            ...      ...                        ...
# 32647             75              1       en  2022-10-01 00:07:05+00:00
# 32648           2963              1       en  2022-10-01 00:06:48+00:00
# 32649           4989              0       en  2022-10-01 00:04:03+00:00
# 32650             66              0       en  2022-10-01 00:03:35+00:00
# 32651           5835              0       en  2022-10-01 00:02:11+00:00
#
#        Number_of_Likes      Source_of_Tweet             Tweet_Id  ...  \
# 0                    0      Twitter Web App  1587232893734207488  ...
# 1                    3  Twitter for Android  1587232353021214722  ...
# 2                    0     Twitter for iPad  1587230288144465922  ...
# 3                    0      Twitter Web App  1587230264295424001  ...
# 4                    1      Twitter Web App  1587229612652003328  ...
# ...                ...                  ...                  ...  ...
# 32647                3      Twitter Web App  1576000715402907648  ...
# 32648                3      Twitter Web App  1576000642430083073  ...
# 32649                1      Twitter Web App  1575999950495698945  ...
# 32650                0      Twitter Web App  1575999832719708160  ...
# 32651                0      Twitter Web App  1575999482000379905  ...
#
#            Conversation_Id                        In_reply_To  Coordinates  \
# 0      1587231188447535105     https://twitter.com/Europaetal          NaN
# 1      1587232353021214722                                NaN          NaN
# 2      1587230281777520643  https://twitter.com/Starbright489          NaN
# 3      1587230264295424001                                NaN          NaN
# 4      1587229612652003328                                NaN          NaN
# ...                    ...                                ...          ...
# 32647  1576000715402907648                                NaN          NaN
# 32648  1576000642430083073                                NaN          NaN
# 32649  1575999950495698945                                NaN          NaN
# 32650  1575999832719708160                                NaN          NaN
# 32651  1575999482000379905                                NaN          NaN
#
#       Place                Date_Tweet1  \
# 0       NaN  2022-10-31 23:59:45+00:00
# 1       NaN  2022-10-31 23:57:36+00:00
# 2       NaN  2022-10-31 23:49:24+00:00
# 3       NaN  2022-10-31 23:49:18+00:00
# 4       NaN  2022-10-31 23:46:43+00:00
# ...     ...                        ...
# 32647   NaN  2022-10-01 00:07:05+00:00
# 32648   NaN  2022-10-01 00:06:48+00:00
# 32649   NaN  2022-10-01 00:04:03+00:00
# 32650   NaN  2022-10-01 00:03:35+00:00
# 32651   NaN  2022-10-01 00:02:11+00:00
#
#                                                    lower  \
# 0      "that doesn't mean[..]that #russia can't splin...
# 1      ukraine starts work on signing declarations wi...
# 2      part 2 of 2/\nnov 3, q&amp;a: #west #misconcep...
# 3      lula's top foreign policy advisor: "lula oppos...
# 4      what is striking is ukraine wants this to be a...
# ...                                                  ...
# 32647  new york city's russian  embassy on the upper ...
# 32648  the war in #ukraine is still going on because ...
# 32649  the russian people are ashamed. the  fake anne...
# 32650  15% of the land that supposedly was under #ukr...
# 32651  #livestreaming: \ncctv: day 219 the ukraine wa...
#
#                                             cleaned_text Sentiment     vader  \
# 0      that meanthat cant splinterthe humaneconomeffe...  NEGATIVE  NEGATIVE
# 1       ukraine starts work signing declarations members   NEUTRAL  NEGATIVE
# 2      part  nov  qa theyll discuss still   exclusive...   NEUTRAL  NEGATIVE
# 3      lulas top foreign policy advisor lula opposes ...   NEUTRAL  NEGATIVE
# 4      striking ukraine wants visual media war whereu...  NEGATIVE  NEGATIVE
# ...                                                  ...       ...       ...
# 32647  new york citys russian embassy upper east side...   NEUTRAL  NEGATIVE
# 32648  war still going rich western world countries f...  NEGATIVE  NEGATIVE
# 32649  russian people ashamed fake annexation list th...  NEGATIVE  NEGATIVE
# 32650   land supposedly part  understood correctly go...  NEGATIVE  NEGATIVE
# 32651               cctv day ukraine war multiple views    NEUTRAL  NEGATIVE
#
#        textblob
# 0       NEUTRAL
# 1       NEUTRAL
# 2       NEUTRAL
# 3      POSITIVE
# 4      POSITIVE
# ...         ...
# 32647  POSITIVE
# 32648  POSITIVE
# 32649  POSITIVE
# 32650  NEGATIVE
# 32651   NEUTRAL
#
# [32652 rows x 22 columns]

# %%
df_test=df_test.dropna(subset=['cleaned_text'])

# %%
df_test
# Out:
#                   User               Date_Created  Follows_Count  \
# 0           Europaetal  2022-03-22 21:23:26+00:00             31
# 1             marra_ua  2022-08-08 11:41:38+00:00             44
# 2        Starbright489  2019-07-27 03:10:29+00:00            211
# 3       geopol_monitor  2013-08-22 09:51:47+00:00           2998
# 4               PCiesa  2021-01-07 01:13:39+00:00             16
# ...                ...                        ...            ...
# 32647         paroliro  2022-09-12 14:14:38+00:00             11
# 32648          tvmario  2009-09-02 15:23:29+00:00           2408
# 32649  Writing_Destiny  2009-04-28 10:18:39+00:00           2704
# 32650    besthealthyou  2013-07-06 19:54:34+00:00            450
# 32651   Suspended_Acct  2012-09-20 15:20:09+00:00           6777
#
#        Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                 56              0       en  2022-10-31 23:59:45+00:00
# 1                  5              1       en  2022-10-31 23:57:36+00:00
# 2               3265              0       en  2022-10-31 23:49:24+00:00
# 3                315              0       en  2022-10-31 23:49:18+00:00
# 4                210              0       en  2022-10-31 23:46:43+00:00
# ...              ...            ...      ...                        ...
# 32647             75              1       en  2022-10-01 00:07:05+00:00
# 32648           2963              1       en  2022-10-01 00:06:48+00:00
# 32649           4989              0       en  2022-10-01 00:04:03+00:00
# 32650             66              0       en  2022-10-01 00:03:35+00:00
# 32651           5835              0       en  2022-10-01 00:02:11+00:00
#
#        Number_of_Likes      Source_of_Tweet             Tweet_Id  ...  \
# 0                    0      Twitter Web App  1587232893734207488  ...
# 1                    3  Twitter for Android  1587232353021214722  ...
# 2                    0     Twitter for iPad  1587230288144465922  ...
# 3                    0      Twitter Web App  1587230264295424001  ...
# 4                    1      Twitter Web App  1587229612652003328  ...
# ...                ...                  ...                  ...  ...
# 32647                3      Twitter Web App  1576000715402907648  ...
# 32648                3      Twitter Web App  1576000642430083073  ...
# 32649                1      Twitter Web App  1575999950495698945  ...
# 32650                0      Twitter Web App  1575999832719708160  ...
# 32651                0      Twitter Web App  1575999482000379905  ...
#
#            Conversation_Id                        In_reply_To  Coordinates  \
# 0      1587231188447535105     https://twitter.com/Europaetal          NaN
# 1      1587232353021214722                                NaN          NaN
# 2      1587230281777520643  https://twitter.com/Starbright489          NaN
# 3      1587230264295424001                                NaN          NaN
# 4      1587229612652003328                                NaN          NaN
# ...                    ...                                ...          ...
# 32647  1576000715402907648                                NaN          NaN
# 32648  1576000642430083073                                NaN          NaN
# 32649  1575999950495698945                                NaN          NaN
# 32650  1575999832719708160                                NaN          NaN
# 32651  1575999482000379905                                NaN          NaN
#
#       Place                Date_Tweet1  \
# 0       NaN  2022-10-31 23:59:45+00:00
# 1       NaN  2022-10-31 23:57:36+00:00
# 2       NaN  2022-10-31 23:49:24+00:00
# 3       NaN  2022-10-31 23:49:18+00:00
# 4       NaN  2022-10-31 23:46:43+00:00
# ...     ...                        ...
# 32647   NaN  2022-10-01 00:07:05+00:00
# 32648   NaN  2022-10-01 00:06:48+00:00
# 32649   NaN  2022-10-01 00:04:03+00:00
# 32650   NaN  2022-10-01 00:03:35+00:00
# 32651   NaN  2022-10-01 00:02:11+00:00
#
#                                                    lower  \
# 0      "that doesn't mean[..]that #russia can't splin...
# 1      ukraine starts work on signing declarations wi...
# 2      part 2 of 2/\nnov 3, q&amp;a: #west #misconcep...
# 3      lula's top foreign policy advisor: "lula oppos...
# 4      what is striking is ukraine wants this to be a...
# ...                                                  ...
# 32647  new york city's russian  embassy on the upper ...
# 32648  the war in #ukraine is still going on because ...
# 32649  the russian people are ashamed. the  fake anne...
# 32650  15% of the land that supposedly was under #ukr...
# 32651  #livestreaming: \ncctv: day 219 the ukraine wa...
#
#                                             cleaned_text Sentiment     vader  \
# 0      that meanthat cant splinterthe humaneconomeffe...  NEGATIVE  NEGATIVE
# 1       ukraine starts work signing declarations members   NEUTRAL  NEGATIVE
# 2      part  nov  qa theyll discuss still   exclusive...   NEUTRAL  NEGATIVE
# 3      lulas top foreign policy advisor lula opposes ...   NEUTRAL  NEGATIVE
# 4      striking ukraine wants visual media war whereu...  NEGATIVE  NEGATIVE
# ...                                                  ...       ...       ...
# 32647  new york citys russian embassy upper east side...   NEUTRAL  NEGATIVE
# 32648  war still going rich western world countries f...  NEGATIVE  NEGATIVE
# 32649  russian people ashamed fake annexation list th...  NEGATIVE  NEGATIVE
# 32650   land supposedly part  understood correctly go...  NEGATIVE  NEGATIVE
# 32651               cctv day ukraine war multiple views    NEUTRAL  NEGATIVE
#
#        textblob
# 0       NEUTRAL
# 1       NEUTRAL
# 2       NEUTRAL
# 3      POSITIVE
# 4      POSITIVE
# ...         ...
# 32647  POSITIVE
# 32648  POSITIVE
# 32649  POSITIVE
# 32650  NEGATIVE
# 32651   NEUTRAL
#
# [31650 rows x 22 columns]

# %%
df_test['cleaned_text'] = df_test['cleaned_text'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-21493ecf3183> in <module>
# ----> 1 df_test['cleaned_text'] = df_test['cleaned_text'].apply(lambda x: word_tokenize(x))
#       2 df.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-40-21493ecf3183> in <lambda>(x)
# ----> 1 df_test['cleaned_text'] = df_test['cleaned_text'].apply(lambda x: word_tokenize(x))
#       2 df.head()
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     """
#     106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107     return tokenizer.tokenize(text)
#     108
#     109
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1274         Given a text, returns a list of the sentences in that text.
#    1275         """
# -> 1276         return list(self.sentences_from_text(text, realign_boundaries))
#    1277
#    1278     def debug_decisions(self, text):
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1330         follows the period.
#    1331         """
# -> 1332         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1333
#    1334     def _match_potential_end_contexts(self, text):
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1330         follows the period.
#    1331         """
# -> 1332         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1333
#    1334     def _match_potential_end_contexts(self, text):
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1320         if realign_boundaries:
#    1321             slices = self._realign_boundaries(text, slices)
# -> 1322         for sentence in slices:
#    1323             yield (sentence.start, sentence.stop)
#    1324
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1419         """
#    1420         realign = 0
# -> 1421         for sentence1, sentence2 in _pair_iter(slices):
#    1422             sentence1 = slice(sentence1.start + realign, sentence1.stop)
#    1423             if not sentence2:
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in _pair_iter(iterator)
#     316     iterator = iter(iterator)
#     317     try:
# --> 318         prev = next(iterator)
#     319     except StopIteration:
#     320         return
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1393     def _slices_from_text(self, text):
#    1394         last_break = 0
# -> 1395         for match, context in self._match_potential_end_contexts(text):
#    1396             if self.text_contains_sentbreak(context):
#    1397                 yield slice(last_break, match.end())
#
# /usr/local/lib/python3.8/dist-packages/nltk/tokenize/punkt.py in _match_potential_end_contexts(self, text)
#    1373         before_words = {}
#    1374         matches = []
# -> 1375         for match in reversed(list(self._lang_vars.period_context_re().finditer(text))):
#    1376             # Ignore matches that have already been captured by matches to the right of this match
#    1377             if matches and match.end() > before_start:
#
# TypeError: expected string or bytes-like object

# %%
X_test = vectorizer.transform(df_test['cleaned_text'])

# %%
y_pred = xgb.predict(X_test)

# %%
len(y_pred)
# Out:
# 31650

# %%
len(df_test)
# Out:
# 31650

# %%
df_test['xgb']=y_pred
# Out:
# <ipython-input-46-636cccc1a94a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['xgb']=y_pred

# %%
df_
# Out:
#                   User               Date_Created  Follows_Count  \
# 0           Europaetal  2022-03-22 21:23:26+00:00             31
# 1             marra_ua  2022-08-08 11:41:38+00:00             44
# 2        Starbright489  2019-07-27 03:10:29+00:00            211
# 3       geopol_monitor  2013-08-22 09:51:47+00:00           2998
# 4               PCiesa  2021-01-07 01:13:39+00:00             16
# ...                ...                        ...            ...
# 32647         paroliro  2022-09-12 14:14:38+00:00             11
# 32648          tvmario  2009-09-02 15:23:29+00:00           2408
# 32649  Writing_Destiny  2009-04-28 10:18:39+00:00           2704
# 32650    besthealthyou  2013-07-06 19:54:34+00:00            450
# 32651   Suspended_Acct  2012-09-20 15:20:09+00:00           6777
#
#        Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                 56              0       en  2022-10-31 23:59:45+00:00
# 1                  5              1       en  2022-10-31 23:57:36+00:00
# 2               3265              0       en  2022-10-31 23:49:24+00:00
# 3                315              0       en  2022-10-31 23:49:18+00:00
# 4                210              0       en  2022-10-31 23:46:43+00:00
# ...              ...            ...      ...                        ...
# 32647             75              1       en  2022-10-01 00:07:05+00:00
# 32648           2963              1       en  2022-10-01 00:06:48+00:00
# 32649           4989              0       en  2022-10-01 00:04:03+00:00
# 32650             66              0       en  2022-10-01 00:03:35+00:00
# 32651           5835              0       en  2022-10-01 00:02:11+00:00
#
#        Number_of_Likes      Source_of_Tweet             Tweet_Id  ...  \
# 0                    0      Twitter Web App  1587232893734207488  ...
# 1                    3  Twitter for Android  1587232353021214722  ...
# 2                    0     Twitter for iPad  1587230288144465922  ...
# 3                    0      Twitter Web App  1587230264295424001  ...
# 4                    1      Twitter Web App  1587229612652003328  ...
# ...                ...                  ...                  ...  ...
# 32647                3      Twitter Web App  1576000715402907648  ...
# 32648                3      Twitter Web App  1576000642430083073  ...
# 32649                1      Twitter Web App  1575999950495698945  ...
# 32650                0      Twitter Web App  1575999832719708160  ...
# 32651                0      Twitter Web App  1575999482000379905  ...
#
#                              In_reply_To Coordinates  Place  \
# 0         https://twitter.com/Europaetal         NaN    NaN
# 1                                    NaN         NaN    NaN
# 2      https://twitter.com/Starbright489         NaN    NaN
# 3                                    NaN         NaN    NaN
# 4                                    NaN         NaN    NaN
# ...                                  ...         ...    ...
# 32647                                NaN         NaN    NaN
# 32648                                NaN         NaN    NaN
# 32649                                NaN         NaN    NaN
# 32650                                NaN         NaN    NaN
# 32651                                NaN         NaN    NaN
#
#                      Date_Tweet1  \
# 0      2022-10-31 23:59:45+00:00
# 1      2022-10-31 23:57:36+00:00
# 2      2022-10-31 23:49:24+00:00
# 3      2022-10-31 23:49:18+00:00
# 4      2022-10-31 23:46:43+00:00
# ...                          ...
# 32647  2022-10-01 00:07:05+00:00
# 32648  2022-10-01 00:06:48+00:00
# 32649  2022-10-01 00:04:03+00:00
# 32650  2022-10-01 00:03:35+00:00
# 32651  2022-10-01 00:02:11+00:00
#
#                                                    lower  \
# 0      "that doesn't mean[..]that #russia can't splin...
# 1      ukraine starts work on signing declarations wi...
# 2      part 2 of 2/\nnov 3, q&amp;a: #west #misconcep...
# 3      lula's top foreign policy advisor: "lula oppos...
# 4      what is striking is ukraine wants this to be a...
# ...                                                  ...
# 32647  new york city's russian  embassy on the upper ...
# 32648  the war in #ukraine is still going on because ...
# 32649  the russian people are ashamed. the  fake anne...
# 32650  15% of the land that supposedly was under #ukr...
# 32651  #livestreaming: \ncctv: day 219 the ukraine wa...
#
#                                             cleaned_text Sentiment     vader  \
# 0      that meanthat cant splinterthe humaneconomeffe...  NEGATIVE  NEGATIVE
# 1       ukraine starts work signing declarations members   NEUTRAL  NEGATIVE
# 2      part  nov  qa theyll discuss still   exclusive...   NEUTRAL  NEGATIVE
# 3      lulas top foreign policy advisor lula opposes ...   NEUTRAL  NEGATIVE
# 4      striking ukraine wants visual media war whereu...  NEGATIVE  NEGATIVE
# ...                                                  ...       ...       ...
# 32647  new york citys russian embassy upper east side...   NEUTRAL  NEGATIVE
# 32648  war still going rich western world countries f...  NEGATIVE  NEGATIVE
# 32649  russian people ashamed fake annexation list th...  NEGATIVE  NEGATIVE
# 32650   land supposedly part  understood correctly go...  NEGATIVE  NEGATIVE
# 32651               cctv day ukraine war multiple views    NEUTRAL  NEGATIVE
#
#        textblob xgb
# 0       NEUTRAL   0
# 1       NEUTRAL   0
# 2       NEUTRAL   0
# 3      POSITIVE   0
# 4      POSITIVE   0
# ...         ...  ..
# 32647  POSITIVE   0
# 32648  POSITIVE   0
# 32649  POSITIVE   0
# 32650  NEGATIVE   0
# 32651   NEUTRAL   0
#
# [31650 rows x 23 columns]

# %%
df_test.reset_index()
# Out:
#        index             User               Date_Created  Follows_Count  \
# 0          0       Europaetal  2022-03-22 21:23:26+00:00             31
# 1          1         marra_ua  2022-08-08 11:41:38+00:00             44
# 2          2    Starbright489  2019-07-27 03:10:29+00:00            211
# 3          3   geopol_monitor  2013-08-22 09:51:47+00:00           2998
# 4          4           PCiesa  2021-01-07 01:13:39+00:00             16
# ...      ...              ...                        ...            ...
# 31645  32647         paroliro  2022-09-12 14:14:38+00:00             11
# 31646  32648          tvmario  2009-09-02 15:23:29+00:00           2408
# 31647  32649  Writing_Destiny  2009-04-28 10:18:39+00:00           2704
# 31648  32650    besthealthyou  2013-07-06 19:54:34+00:00            450
# 31649  32651   Suspended_Acct  2012-09-20 15:20:09+00:00           6777
#
#        Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                 56              0       en  2022-10-31 23:59:45+00:00
# 1                  5              1       en  2022-10-31 23:57:36+00:00
# 2               3265              0       en  2022-10-31 23:49:24+00:00
# 3                315              0       en  2022-10-31 23:49:18+00:00
# 4                210              0       en  2022-10-31 23:46:43+00:00
# ...              ...            ...      ...                        ...
# 31645             75              1       en  2022-10-01 00:07:05+00:00
# 31646           2963              1       en  2022-10-01 00:06:48+00:00
# 31647           4989              0       en  2022-10-01 00:04:03+00:00
# 31648             66              0       en  2022-10-01 00:03:35+00:00
# 31649           5835              0       en  2022-10-01 00:02:11+00:00
#
#        Number_of_Likes      Source_of_Tweet  ...  \
# 0                    0      Twitter Web App  ...
# 1                    3  Twitter for Android  ...
# 2                    0     Twitter for iPad  ...
# 3                    0      Twitter Web App  ...
# 4                    1      Twitter Web App  ...
# ...                ...                  ...  ...
# 31645                3      Twitter Web App  ...
# 31646                3      Twitter Web App  ...
# 31647                1      Twitter Web App  ...
# 31648                0      Twitter Web App  ...
# 31649                0      Twitter Web App  ...
#
#                              In_reply_To Coordinates Place  \
# 0         https://twitter.com/Europaetal         NaN   NaN
# 1                                    NaN         NaN   NaN
# 2      https://twitter.com/Starbright489         NaN   NaN
# 3                                    NaN         NaN   NaN
# 4                                    NaN         NaN   NaN
# ...                                  ...         ...   ...
# 31645                                NaN         NaN   NaN
# 31646                                NaN         NaN   NaN
# 31647                                NaN         NaN   NaN
# 31648                                NaN         NaN   NaN
# 31649                                NaN         NaN   NaN
#
#                      Date_Tweet1  \
# 0      2022-10-31 23:59:45+00:00
# 1      2022-10-31 23:57:36+00:00
# 2      2022-10-31 23:49:24+00:00
# 3      2022-10-31 23:49:18+00:00
# 4      2022-10-31 23:46:43+00:00
# ...                          ...
# 31645  2022-10-01 00:07:05+00:00
# 31646  2022-10-01 00:06:48+00:00
# 31647  2022-10-01 00:04:03+00:00
# 31648  2022-10-01 00:03:35+00:00
# 31649  2022-10-01 00:02:11+00:00
#
#                                                    lower  \
# 0      "that doesn't mean[..]that #russia can't splin...
# 1      ukraine starts work on signing declarations wi...
# 2      part 2 of 2/\nnov 3, q&amp;a: #west #misconcep...
# 3      lula's top foreign policy advisor: "lula oppos...
# 4      what is striking is ukraine wants this to be a...
# ...                                                  ...
# 31645  new york city's russian  embassy on the upper ...
# 31646  the war in #ukraine is still going on because ...
# 31647  the russian people are ashamed. the  fake anne...
# 31648  15% of the land that supposedly was under #ukr...
# 31649  #livestreaming: \ncctv: day 219 the ukraine wa...
#
#                                             cleaned_text Sentiment     vader  \
# 0      that meanthat cant splinterthe humaneconomeffe...  NEGATIVE  NEGATIVE
# 1       ukraine starts work signing declarations members   NEUTRAL  NEGATIVE
# 2      part  nov  qa theyll discuss still   exclusive...   NEUTRAL  NEGATIVE
# 3      lulas top foreign policy advisor lula opposes ...   NEUTRAL  NEGATIVE
# 4      striking ukraine wants visual media war whereu...  NEGATIVE  NEGATIVE
# ...                                                  ...       ...       ...
# 31645  new york citys russian embassy upper east side...   NEUTRAL  NEGATIVE
# 31646  war still going rich western world countries f...  NEGATIVE  NEGATIVE
# 31647  russian people ashamed fake annexation list th...  NEGATIVE  NEGATIVE
# 31648   land supposedly part  understood correctly go...  NEGATIVE  NEGATIVE
# 31649               cctv day ukraine war multiple views    NEUTRAL  NEGATIVE
#
#        textblob xgb
# 0       NEUTRAL   0
# 1       NEUTRAL   0
# 2       NEUTRAL   0
# 3      POSITIVE   0
# 4      POSITIVE   0
# ...         ...  ..
# 31645  POSITIVE   0
# 31646  POSITIVE   0
# 31647  POSITIVE   0
# 31648  NEGATIVE   0
# 31649   NEUTRAL   0
#
# [31650 rows x 24 columns]

# %%
df_test.to_csv("aws_vader_textblob_xgb" + "_" + "oct" + "_" + "result" + ".csv", index=False)
